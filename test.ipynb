# %%
import pandas as pd
pd.options.display.max_rows = 10
el_pais = pd.read_csv('./elpais_2021_11_07_articles.csv')
el_pais
# Out:
#                                                   body  \
# 0    \r\nLa procuradora Ernestina Godoy confirmó qu...
# 1                                                  NaN
# 2                                                  NaN
# 3    \r\n\r\nTras el triunfo de Barbosa y la derrot...
# 4    \r\n\r\nLa noticia de que las niñas y niños de...
# ..                                                 ...
# 194  \r\nCDMX.- Cerca de las 18:30 horas, un hombre...
# 195  \r\nTexto: Aída Castro SánchezDiseño web: Migu...
# 196  \r\nTingüindín, Michoacán.- Diego Vidal Manzo,...
# 197                                                NaN
# 198                                                NaN
#
#                                                  title  \
# 0    Matan a exdiputado de Tláhuac; investigan vínc...
# 1                                                  NaN
# 2                                                  NaN
# 3    Puebla: un tropiezo electoral no es una derrot...
# ...

# %%
el_pais.iloc[:, ]
# Out:
#                                                   body  \
# 0    \r\nLa procuradora Ernestina Godoy confirmó qu...
# 1                                                  NaN
# 2                                                  NaN
# 3    \r\n\r\nTras el triunfo de Barbosa y la derrot...
# 4    \r\n\r\nLa noticia de que las niñas y niños de...
# ..                                                 ...
# 194  \r\nCDMX.- Cerca de las 18:30 horas, un hombre...
# 195  \r\nTexto: Aída Castro SánchezDiseño web: Migu...
# 196  \r\nTingüindín, Michoacán.- Diego Vidal Manzo,...
# 197                                                NaN
# 198                                                NaN
#
#                                                  title  \
# 0    Matan a exdiputado de Tláhuac; investigan vínc...
# 1                                                  NaN
# 2                                                  NaN
# 3    Puebla: un tropiezo electoral no es una derrot...
# ...

# %%
el_pais['newspaper_uid'] = 'elpais'
el_pais
# Out:
#                                                   body  \
# 0    \r\nLa procuradora Ernestina Godoy confirmó qu...
# 1                                                  NaN
# 2                                                  NaN
# 3    \r\n\r\nTras el triunfo de Barbosa y la derrot...
# 4    \r\n\r\nLa noticia de que las niñas y niños de...
# ..                                                 ...
# 194  \r\nCDMX.- Cerca de las 18:30 horas, un hombre...
# 195  \r\nTexto: Aída Castro SánchezDiseño web: Migu...
# 196  \r\nTingüindín, Michoacán.- Diego Vidal Manzo,...
# 197                                                NaN
# 198                                                NaN
#
#                                                  title  \
# 0    Matan a exdiputado de Tláhuac; investigan vínc...
# 1                                                  NaN
# 2                                                  NaN
# 3    Puebla: un tropiezo electoral no es una derrot...
# ...

# %%
from urllib.parse import urlparse
el_pais['host'] = el_pais['url'].apply(lambda url: urlparse(url).netloc)
el_pais
# Out:
#                                                   body  \
# 0    \r\nLa procuradora Ernestina Godoy confirmó qu...
# 1                                                  NaN
# 2                                                  NaN
# 3    \r\n\r\nTras el triunfo de Barbosa y la derrot...
# 4    \r\n\r\nLa noticia de que las niñas y niños de...
# ..                                                 ...
# 194  \r\nCDMX.- Cerca de las 18:30 horas, un hombre...
# 195  \r\nTexto: Aída Castro SánchezDiseño web: Migu...
# 196  \r\nTingüindín, Michoacán.- Diego Vidal Manzo,...
# 197                                                NaN
# 198                                                NaN
#
#                                                  title  \
# 0    Matan a exdiputado de Tláhuac; investigan vínc...
# 1                                                  NaN
# 2                                                  NaN
# 3    Puebla: un tropiezo electoral no es una derrot...
# ...

# %%
el_pais['host'].value_counts()
# Out:
# www.eluniversal.com.mx             115
# www.viveusa.mx                       9
# www.elbotiquin.mx                    9
# bit.ly                               8
# www.tangible-eluniversal.com.mx      7
#                                   ...
# www.unionyucatan.mx                  1
# interactivo.eluniversal.com.mx       1
# twitter.com                          1
# www.facebook.com                     1
# www.unionguanajuato.mx               1
# Name: host, Length: 22, dtype: int64

# %%
missing_title_mask = el_pais['title'].isna()
el_pais[missing_title_mask]['url'].str.extract(r'(?P<missing_title>[^/]+)$').applymap(str).applymap(lambda title: title.replace('-', ' '))
# Out:
#                                          missing_title
# 1                                                  box
# 2    en verdad padecio sifilis schubert el gran com...
# 6    ladron se dispara durante asalto pizzeria en m...
# 9    las bacterias que viven en tu celular y otros ...
# 10                                             2jmdiXT
# ..                                                 ...
# 182  10 famosos que lucen irreconocibles con unos k...
# 188                                      suscripciones
# 191                                            1TWQKcr
# 192             6 ejercicios para tonificar los brazos
# 197                                          seguridad
#
# [65 rows x 1 columns]
